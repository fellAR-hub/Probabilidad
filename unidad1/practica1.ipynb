# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad1/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Abrego Reyea Angel Felipe
# ### **Programa 1:Estadistica basica e Histogramas

# %%
from statistics import *
grupoa=[20,87,98,99,100,100,50,68,70,80,84,24]
print(grupoa)
type(grupoa)
promedio=sum(grupoa)/len(grupoa)
print(promedio)
promedio2=mean(grupoa)
print(promedio2)
mediana=median(grupoa)
print(mediana)
moda=mode(grupoa)
print(moda)
moda2=multimode(grupoa)
print(moda2)
# Out:
# [20, 87, 98, 99, 100, 100, 50, 68, 70, 80, 84, 24]
# 73.33333333333333
# 73.33333333333333
# 82.0
# 100
# [100]

# %%
tiempos100mts=[14.05,22.52,66.12,43.10,11.11,15.67,30.88,25.34,12.44,53.41]
print(tiempos100mts)



print("tiempo promedio de los corredores:",mean(tiempos100mts))
print("tiempo mediano de los corredores:",median(tiempos100mts))
print("tiempo de la moda de los corredores:",mode(tiempos100mts))
# Out:
# [14.05, 22.52, 66.12, 43.1, 11.11, 15.67, 30.88, 25.34, 12.44, 53.41]
# tiempo promedio de los corredores: 29.464
# tiempo mediano de los corredores: 23.93
# tiempo de la moda de los corredores: 14.05

# %%
import random
fabrica1=[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
print("-------------------------------")
fabrica2=[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [95.4, 76.71, 51.25, 66.68, 67.51, 58.45, 98.21, 72.85, 58.4, 91.81, 71.18, 52.15, 56.31, 61.67, 79.06, 74.67, 63.64, 70.95, 66.56, 80.78, 88.7, 88.79, 85.04, 74.92, 91.11, 52.68, 62.12, 55.46, 98.12, 65.98, 91.41, 80.75, 58.78, 76.81, 82.17, 71.52, 89.37, 67.92, 92.15, 85.23, 75.59, 97.7, 96.92, 61.37, 71.01, 60.21, 85.34, 50.94, 62.52, 52.52, 91.09, 71.0, 67.27, 94.43, 83.67, 53.75, 55.97, 96.0, 60.67, 50.51, 70.11, 66.58, 63.66, 97.5, 50.98, 96.65, 72.58, 74.17, 89.93, 60.14, 66.16, 98.67, 59.99, 86.37, 85.89, 54.61, 97.1, 95.52, 90.21, 75.08, 80.63, 92.89, 97.73, 65.81, 83.87, 67.01, 66.32, 51.62, 64.35, 63.43, 91.26, 78.97, 50.2, 89.08, 62.41, 93.98, 54.74, 59.39, 54.1, 58.15]
# -------------------------------
# ...
