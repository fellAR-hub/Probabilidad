# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad1/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##UNIDAD 1
# ###FACILITADOR: RODRIGUEZ RIVAS JOSE GABRIEL
# ###ALUMNO: ABREGO REYES ANGEL FELIPE

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = [ ]
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100),2)
  fabrica1.append (numero_aleatorio)
print(fabrica1)
# Out:
# [81.98, 54.29, 99.64, 84.23, 72.65, 82.95, 73.28, 60.1, 87.18, 60.3, 61.38, 51.04, 59.8, 72.23, 73.39, 50.8, 60.29, 94.91, 78.29, 94.98, 72.91, 75.67, 87.29, 95.55, 74.96, 54.44, 99.02, 75.36, 87.79, 62.61, 99.13, 90.56, 98.12, 61.71, 96.19, 83.09, 85.87, 58.58, 72.61, 78.24, 98.79, 63.75, 87.3, 91.55, 58.46, 92.87, 61.5, 74.5, 75.14, 65.57, 59.59, 86.91, 60.06, 81.98, 66.03, 68.17, 54.28, 65.91, 90.65, 69.32, 97.75, 97.9, 84.67, 60.38, 88.48, 89.48, 61.98, 50.25, 65.64, 59.11, 65.85, 78.49, 56.96, 68.53, 93.56, 79.19, 80.51, 55.11, 97.22, 94.0, 99.38, 96.2, 95.28, 61.74, 57.9, 65.62, 85.49, 64.9, 52.19, 100.0, 84.62, 94.44, 82.81, 61.78, 92.14, 58.86, 99.3, 82.98, 93.81, 83.4]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40, 93), 2 )
  fabrica2. append (numero_aleatorio)
print(fabrica2)
# Out:
# [41.03, 85.25, 91.4, 81.87, 40.69, 42.73, 63.91, 69.73, 68.69, 63.55, 64.62, 56.42, 49.53, 62.92, 66.19, 46.25, 67.79, 73.72, 43.84, 67.38, 49.46, 51.18, 72.15, 73.76, 52.1, 71.84, 40.21, 42.91, 75.39, 50.09, 86.7, 63.2, 67.61, 45.18, 53.36, 65.31, 67.99, 46.73, 68.32, 79.16, 70.33, 63.46, 84.76, 92.46, 78.87, 74.52, 42.05, 71.08, 63.26, 54.87, 84.48, 82.78, 40.94, 53.69, 52.71, 46.23, 67.0, 47.36, 74.86, 77.55, 71.74, 91.76, 44.12, 69.78, 71.46, 42.55, 59.07, 63.03, 84.95, 84.14, 92.55, 60.67, 72.9, 54.17, 88.83, 54.44, 59.37, 91.64, 50.45, 46.99, 70.57, 90.41, 73.43, 91.55, 51.09, 54.12, 75.56, 74.17, 54.04, 55.1, 51.51, 49.04, 67.4, 60.7, 73.67, 60.8, 74.9, 47.81, 54.97, 58.83]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
vert=True, # Alineacion Vertical
patch_artist=True) # Rellenar con color
ax1.set_title('Producción fabrica 1')

bplot2 = ax2.boxplot (fabrica2,
                      vert=True, # Alineacion Vertical
                      patch_artist=True) # Rellenar con
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
#Insertamos un valor de 150 a La fabrica 1,
#Sería un valor atipico
fabrica1.append(150)
print(fabrica1)
# Out:
# [81.98, 54.29, 99.64, 84.23, 72.65, 82.95, 73.28, 60.1, 87.18, 60.3, 61.38, 51.04, 59.8, 72.23, 73.39, 50.8, 60.29, 94.91, 78.29, 94.98, 72.91, 75.67, 87.29, 95.55, 74.96, 54.44, 99.02, 75.36, 87.79, 62.61, 99.13, 90.56, 98.12, 61.71, 96.19, 83.09, 85.87, 58.58, 72.61, 78.24, 98.79, 63.75, 87.3, 91.55, 58.46, 92.87, 61.5, 74.5, 75.14, 65.57, 59.59, 86.91, 60.06, 81.98, 66.03, 68.17, 54.28, 65.91, 90.65, 69.32, 97.75, 97.9, 84.67, 60.38, 88.48, 89.48, 61.98, 50.25, 65.64, 59.11, 65.85, 78.49, 56.96, 68.53, 93.56, 79.19, 80.51, 55.11, 97.22, 94.0, 99.38, 96.2, 95.28, 61.74, 57.9, 65.62, 85.49, 64.9, 52.19, 100.0, 84.62, 94.44, 82.81, 61.78, 92.14, 58.86, 99.3, 82.98, 93.81, 83.4, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
vert=True, # vertical box alignment
patch_artist=True) # fill with color
ax1.set_title('Producción fabrica 1')
bplot2 = ax2.boxplot(fabrica2,
vert=True, # vertical box alignment
patch_artist=True) # fill with color
ax2.set_title('Producción fabrica 2')
plt.show()

# %%
# Agregamos ax1.set_ylim(0, 160) para garantizar que ambos gráficos usen La
# misma escala vertical, facilitando La comparación visual.
fig, (ax1, ax2) = plt.subplots (nrows=1, ncols=2, figsize=(9, 5))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True, # Alineacion Vertical t
                      patch_artist=True) # Rellenar con color
ax1.set_title('Producción fabrica 1')
ax1.set_ylim(30, 160) # Escala Uniforme de 0 a 160

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # Alineacion Vertical t
                     patch_artist=True) # Rellenar con color
ax2.set_title('Producción fabrica 2')
ax2.set_ylim(30, 160) # Escala Uniforme de 0 a 160
plt.show()
