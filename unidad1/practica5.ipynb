# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad1/practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# ##Unidad 1
# ###Facilitador:Rodriguez Rivas Jose Gabriel
# ###Alumna:Abrego Reyes Angel Felipe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot

# %%
autos = pd.read_csv('autos2.csv')

# %%
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
precio_min    = autos['price'].min()
precio_max    = autos['price'].max()
precio_moda   = autos['price'].mode()[0]
precio_media  = autos['price'].mean()
precio_mediana = autos['price'].median()

print(f"Valor mínimo:  ${precio_min:,.2f}")
print(f"Valor máximo:  ${precio_max:,.2f}")
print(f"Moda:          ${precio_moda:,.2f}")
print(f"Media:         ${precio_media:,.2f}")
print(f"Mediana:       ${precio_mediana:,.2f}")
# Out:
# Valor mínimo:  $5,118.00
# Valor máximo:  $45,400.00
# Moda:          $5,572.00
# Media:         $13,207.13
# Mediana:       $10,295.00

# %%
precio_std = autos['price'].std()
print(f"Desviación estándar: ${precio_std:,.2f}")

estadisticos = autos['price'].describe()
print("\nEstadísticos completos:")
print(estadisticos)
# Out:
# Desviación estándar: $7,947.07
#
# Estadísticos completos:
# count      201.000000
# mean     13207.129353
# std       7947.066342
# min       5118.000000
# 25%       7775.000000
# 50%      10295.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
import numpy as np

# Regla de Sturges
n = autos['price'].dropna().count()
bins_sturges = int(1 + np.log2(n))
print(f"Número de registros (n): {n}")
print(f"Bins según Regla de Sturges: {bins_sturges}")

# Histograma
plt.figure(figsize=(10, 6))
plt.hist(autos['price'].dropna(), bins=bins_sturges, color='steelblue', edgecolor='black')

plt.title('Distribución de Precios de Automóviles', fontsize=16, fontweight='bold')
plt.xlabel('Precio (USD)', fontsize=13)
plt.ylabel('Frecuencia', fontsize=13)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Número de registros (n): 201
# Bins según Regla de Sturges: 8

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='body-style', y='price', data=autos, palette='Set2')

plt.title('Relación entre Precio y Tipo de Vehículo', fontsize=16, fontweight='bold')
plt.xlabel('Tipo de Vehículo (Body Style)', fontsize=13)
plt.ylabel('Precio (USD)', fontsize=13)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1749682052.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='body-style', y='price', data=autos, palette='Set2')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='drive-wheels', y='price', data=autos, palette='Set1')

plt.title('Relación entre Precio y Tipo de Tracción', fontsize=16, fontweight='bold')
plt.xlabel('Tipo de Tracción (Drive Wheels)', fontsize=13)
plt.ylabel('Precio (USD)', fontsize=13)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1463467093.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='drive-wheels', y='price', data=autos, palette='Set1')

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='engine-location', y='price', data=autos, palette='coolwarm')

plt.title('Relación entre Precio y Ubicación del Motor', fontsize=16, fontweight='bold')
plt.xlabel('Ubicación del Motor (Engine Location)', fontsize=13)
plt.ylabel('Precio (USD)', fontsize=13)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1534874819.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='engine-location', y='price', data=autos, palette='coolwarm')

# %% [markdown]
# #CONCLUCION
# ######Durante esta práctica se utilizaron diversas funciones de Python y librerías como Pandas, NumPy, Matplotlib y Seaborn para el análisis y visualización de datos de automóviles. Mediante el histograma de precios se observó que la mayoría de los autos se concentran en rangos de precio bajos y medios, lo que indica una mayor preferencia por vehículos del segmento económico. Asimismo, en los diagramas de caja se evidenció que el precio varía según características como el tipo de carrocería, el tipo de tracción y la ubicación del motor. En particular, el boxplot de tracción mostró que la tracción delantera (FWD) predomina en los autos de menor precio, mientras que la tracción trasera (RWD) se asocia con precios más elevados.
