# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad3/practicapendiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 3
# ##Probabilidad y estadistica
# ##Ejercicio 1
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Abrego Reyes Angel Felipe

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([0,1,2,3,4,5])
p = np.array([0.10,0.25,0.30,0.20,0.10,0.05])

print("Suma de probabilidades:", np.sum(p))
E = np.sum(x * p)
print("Valor esperado:", E)

var = np.sum((x - E)**2 * p)
std = np.sqrt(var)
print("Varianza:", var)
print("Desviación estándar:", std)


cdf = np.cumsum(p)
print("CDF:", cdf)

plt.step(x, cdf, where='post')
plt.xlabel("X")
plt.ylabel("F(x)")
plt.title("Función de distribución acumulada")
plt.grid()
plt.show()
# Out:
# Suma de probabilidades: 0.9999999999999999
# Valor esperado: 2.1
# Varianza: 1.6900000000000002
# Desviación estándar: 1.3
# CDF: [0.1  0.35 0.65 0.85 0.95 1.  ]
