# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad3/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad3
# ##Probabilidad y estadistica
# ##Valor esperado
# ###Facilitador:Jose Gabriel Rodriguez Rivas
# ###alumno:Abrego Reyes Angel Felipe

# %%
import math
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]
esperanza=0
for i in range(len(x)):
  esperanza += x[i]*p[i]
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado+= (x[i]**2)*p[i]
  varianza=esperanza_cuadrado-esperanza**2
  desviacion=math.sqrt(varianza)
  print(f"E(x)={esperanza:.2f}")
  print(f"E(X^2)={esperanza_cuadrado:.2f}")
  print(f"varianza={varianca:.2f}")
  print(f"Desviacion estandar={desviacion:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_222/204262291.py in <cell line: 0>()
#       9   esperanza_cuadrado+= (x[i]**2)*p[i]
#      10   varianza=esperanza_cuadrado-esperanza**2
# ---> 11   desviacion=math.sqrt(varianza)
#      12   print(f"E(x)={esperanza:.2f}")
#      13   print(f"E(X^2)={esperanza_cuadrado:.2f}")
#
# ValueError: math domain error
