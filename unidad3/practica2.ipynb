# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad3/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad3
# ##Probabilidad y estadistica
# ##Valor esperado
# ###Facilitador:Jose Gabriel Rodriguez Rivas
# ###alumno:Abrego Reyes Angel Felipe

# %%
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]
valor_esperado = 0
for i in range(len(x)):
  xi=x[i]
  pi=p[i]
  producto=xi*pi
  valor_esperado +=producto
  print(f"x={xi},p={pi},x*p={producto:.2f}")
print(f"\nValor esperado(esperanza):{valor_esperado:.2f}")
# Out:
# x=5,p=0.05,x*p=0.25
# x=6,p=0.1,x*p=0.60
# x=7,p=0.2,x*p=1.40
# x=8,p=0.3,x*p=2.40
# x=9,p=0.25,x*p=2.25
# x=10,p=0.1,x*p=1.00
#
# Valor esperado(esperanza):7.90
