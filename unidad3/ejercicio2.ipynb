# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad3/ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 3
# ##Probabilidad y estadistica
# ##Ejercicio 2
# ###Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Abrego Reyes Angel Felipe

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
valores = np.array([0, 10, 20, 50])
probabilidades = np.array([0.50, 0.30, 0.15, 0.05])

# 1. Verificar que las probabilidades suman 1
suma_prob = np.sum(probabilidades)
print("Suma de probabilidades:", suma_prob)

# 2. Distribución de probabilidad (ya está dada, pero la mostramos bonito)
print("\nDistribución de probabilidad:")
for x, p in zip(valores, probabilidades):
    print(f"X = {x}, P(X) = {p}")

# 3. Cálculos

# Valor esperado
E = np.sum(valores * probabilidades)
print("\nValor esperado E(X):", E)

# Varianza
varianza = np.sum(probabilidades * (valores - E)**2)
print("Varianza:", varianza)

# Desviación estándar
desv_std = np.sqrt(varianza)
print("Desviación estándar:", desv_std)

# 4. Función de distribución acumulada (FDA)
F = np.cumsum(probabilidades)

print("\nFunción de distribución acumulada:")
for x, f in zip(valores, F):
    print(f"F({x}) = {f}")

# Gráfica de la FDA
plt.step(valores, F, where='post')
plt.xlabel("X")
plt.ylabel("F(x)")
plt.title("Función de Distribución Acumulada")
plt.grid()
plt.show()
# Out:
# Suma de probabilidades: 1.0
#
# Distribución de probabilidad:
# X = 0, P(X) = 0.5
# X = 10, P(X) = 0.3
# X = 20, P(X) = 0.15
# X = 50, P(X) = 0.05
#
# Valor esperado E(X): 8.5
# Varianza: 142.75
# Desviación estándar: 11.947803145348521
#
# Función de distribución acumulada:
# F(0) = 0.5
# F(10) = 0.8
# F(20) = 0.9500000000000001
# F(50) = 1.0
