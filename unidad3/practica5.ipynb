# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad3/practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 3
# #Probabilidad y estadistica
# ##Grafica de distribucion de probabilidad
# ###Facilitador:Jose Gabriel Rodriguez Rivas
# ###Alumno: Angel Felipe Abrego Reyes

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5, 6, 7, 8, 9, 10])
p = np.array([0.05, 0.10, 0.20, 0.30, 0.25, 0.10])

esperanza = np.sum(x * p)


esperanza_cuadrado = np.sum(x**2 * p)

varianza = esperanza_cuadrado - esperanza**2
desviacion = np.sqrt(varianza)


print(f"E(X) = {esperanza:.2f}")
print(f"E(X^2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")


plt.stem(x, p, basefmt=" ", linefmt='b-', markerfmt='bo')

plt.title("Distribución de Probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Valores de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--', alpha=0.6)


plt.axvline(x=esperanza, color='red', linestyle='--',
            label=f"Media (E[X]) = {esperanza:.2f}")

plt.axvspan(esperanza - desviacion, esperanza + desviacion,
            color='red', alpha=0.2,
            label=f"±1 Desv. Estándar = {desviacion:.2f}")

plt.legend()
plt.ylim(0, max(p) + 0.05)
plt.xticks(x)

plt.show()
# Out:
# E(X) = 7.90
# E(X^2) = 64.10
# Varianza = 1.69
# Desviación estándar = 1.30
