# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad4/distribucion_T_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
# #Unidad4
# ##Distribucion T-Student
# ###Facilitador:Jose Gabriel Rodriguez Rivas
# ###Alumno:Angel Felipe abrego Reyes

# %%
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt
data=np.array([118,125,130,128,122,135,129,129,127,124])
n=len(data)
media=np.mean(data)
desv_std=np.std(data,ddof=1)
alpha=0.05
df=n-1
t_critico=t.ppf(1-alpha/2,df)
error=t_critico*(desv_std/np.sqrt(n))
lim_inf=media-error
lim_sup=media+error
print(f"media muestral={media:.2f}mmHg")
print(f"desviacion estandar={desv_std:.2f}mmHg"
)
print(f"grados de libertad={df}")
print(f"valor critico t={t_critico:.3f}")
print(f"intervalo de confianza 95%:[{lim_inf:.2f},{lim_sup:.2f}]mmHg"
)
# Out:
# media muestral=126.70mmHg
# desviacion estandar=4.72mmHg
# grados de libertad=9
# valor critico t=2.262
# intervalo de confianza 95%:[123.33,130.07]mmHg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_826/2329467984.py in <cell line: 0>()
#      20 )
#      21 plt.figure(figsize=(8,5))
# ---> 22 plt.plot(x, y, color='navy',label='distribucion t de la media muestral')
#      23 plt.axvline(lim_inf,color='red',linestyle='--',label='limite inferior')
#      24 plt.axvline(lim_sup,color='red',linestyle='--',label='limite superior')
#
# NameError: name 'x' is not defined

# %%
x=np.linspace(media-3*desv_std,media+3*desv_std,200)
y=t.pdf((x-media)/(desv_std/np.sqrt(n)),df)
plt.figure(figsize=(8,5))
plt.plot(x,y,color='navy',label='distribucion t de la media muestral')
plt.axvline(lim_inf,color='red',linestyle='--',label='limite inferior')
plt.axvline(lim_sup,color='red',linestyle='--',label='limite superior')
plt.axvline(media,color='green',linestyle='-',label='media muestral')
plt.title('intervalo de confianza del 95% para la media(t de student)')
plt.xlabel('presion arterial(mmHg)')
plt.ylabel('densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
