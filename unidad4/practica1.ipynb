# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad4/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
media=70
desv_std=4
num_datos=500
datos=np.random.normal(media,desv_std,num_datos)
datos[0:50]
# Out:
# array([65.06442215, 69.19658747, 74.93275939, 75.04661043, 66.07169751,
#        63.40372113, 73.74485736, 72.11387827, 74.54204913, 68.2970942 ,
#        68.03961901, 69.27368732, 65.95768275, 67.4196941 , 67.9736601 ,
#        67.34274246, 62.91222049, 72.50513979, 74.43702121, 69.74985906,
#        68.93726169, 76.32215137, 67.2516875 , 70.0326835 , 71.63721716,
#        71.18606408, 68.58090236, 71.06188143, 66.68181265, 76.65333312,
#        66.57521314, 68.0097718 , 70.21452349, 66.03289194, 76.67697824,
#        66.36782204, 65.32816855, 67.046173  , 65.24450196, 79.07006423,
#        64.28951601, 65.68144408, 65.99242927, 73.3068429 , 67.03505794,
#        73.7138558 , 68.33831815, 69.33000711, 65.91831336, 70.68553868])

# %%
x=np.linspace(media-3*desv_std,media+3*desv_std,num_datos)
pdf=1/(desv_std * np.sqrt(2*np.pi))*np.exp(-(x-media)**2/(2*desv_std**2))
print("imprimir los primeros 50 valores de x:",x[0:50],", y los primeros 50 pdf:"[0:50])
# Out:
# imprimir los primeros 50 valores de x: [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343] , y los primeros 50 pdf:

# %%
plt.figure(figsize=(6,4))
plt.hist(datos,bins=15,alpha=0.4,color='b')
plt.title("distribucion normal")
plt.xlabel('peso en kg de los estudiantes')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(6,4))
plt.plot(x,pdf,label="Normal(media:{};ds{})".format(np.round(media,2),np.round(desv_std,2)))
plt.title('Funcio de densidad de probabilidad(PDF)-Distribucion Normal')
plt.xlabel('pesos en kg. de los estudiantes')
plt.ylabel('densidad de probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(datos,bins=15,alpha=0.4,density=True,color='b')
plt.plot(x,pdf,'k',linewidth=2,)
plt.title('distribucion normal')
plt.xlabel('peso en kg de los estudiantes')
plt.grid(True)
plt.show()
