# %% [markdown]
# <a href="https://colab.research.google.com/github/fellAR-hub/Probabilidad/blob/main/unidad4/distribucion_de_poisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBABILIDAD Y ESTADISTICA
# #UNIDAD 4
# ##Distribucion de Poisson
# ###Facilitador:Jose Gabriel Rodriguez Rivas
# ###Alumno:Abrego Reyes Angel Felipe

# %%
from scipy.stats import poisson
media_accidentes=2
probabilidad_0_accidentes=poisson.pmf(0,media_accidentes)
print("1. Probabilidad de que no haya acciones en 1 semana:",probabilidad_0_accidentes)
media_2_semanas=media_accidentes*2
probabilidad_3_o_menos_accidentes=poisson.cdf(3,media_2_semanas)
print("2. probabilidad de que a lo sumo haya 3 accidentes en 2 semanas:",probabilidad_3_o_menos_accidentes)
# Out:
# 1. Probabilidad de que no haya acciones en 1 semana: 0.1353352832366127
# 2. probabilidad de que a lo sumo haya 3 accidentes en 2 semanas: 0.43347012036670896

# %%
media_muertes=5000*0.001
x=4
probabilidad_4_reclamaciones=poisson.pmf(x,media_muertes)
print("la probabilidad de que la compañia tenga que pagar 4 reclamaciones es de:",probabilidad_4_reclamaciones)
# Out:
# la probabilidad de que la compañia tenga que pagar 4 reclamaciones es de: 0.17546736976785063
